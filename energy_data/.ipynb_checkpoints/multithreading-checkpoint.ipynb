# %%
from threading import Thread, Event
import numpy
import pandas


class Rl_Env:
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
    def set_events(self, event_rl, event_device):
        self.event_rl = event_rl
        self.event_device = event_device

    def set_device(self, device):
        self.device = device

    
class Aggregator:
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
    
    def set_events(self, event_rl, event_device):
        self.event_rl = event_rl
        self.event_device = event_device

    def set_RLEnv(self, rl_env):
        self.rl_env = rl_env
        
    def on_market_cycle():
        print(f'On market cycle')
        
        
        
        if(self.event_rl.isSet()):
            print('SIMULATION RUNS TOO FAST!')


    
def thread_rl():
    print("RL")

def thread_device():
    print("Device")
    # loop to allow persistence
    while not test_b.is_finished:
        sleep(0.5)
    
    
    
    
    
    
# aggregator
aggr = Aggregator()

    
# Init multithreading events
event_rl = Event()
event_device = Event()

# Init rl_env
rl_env = Rl_Env()

# Set events according to both env
aggr.set_RLEnv(rl_env)
rl_env.set_device(aggr)
aggr.set_events(event_rl, event_device)
rl_env.set_events(event_rl, event_device)

# Init both threads
rl_thread = Thread(name='RL Thread', target=thread_rl, args=())
dv_thread = Thread(name='Device Thread', target=thread_device, args=())

# Starting the threads
rl_thread.start()
dv_thread.start()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-7a81ef380729> in <module>
#      56 # Set events according to both env
#      57 aggr.set_RLEnv(rl_env)
# ---> 58 rl_env.set_device(aggr)
#      59 aggr.set_events(event_rl, event_device)
#      60 rl_env.set_events(event_rl, event_device)
#
# AttributeError: 'Rl_Env' object has no attribute 'set_device'
